# %%
import pandas as pds
import numpy as np
import matplotlib.pyplot as plt

# %%
df_listings_final = pds.read_csv("https://storage.googleapis.com/h3-data/listings_final.csv", sep=";")
df_price_availability = pds.read_csv("https://storage.googleapis.com/h3-data/price_availability.csv", sep=";")

# %%
df_listings_final.head()
# Out:
#    Unnamed: 0  listing_id                                      name  \
# 0           0    28581061                           La maison Clery
# 1           1      661961       studio PARIS PLACE EDITH PIAF 75020
# 2           2     1261705  chambre privée à louer @ paris oberkampf
# 3           3     1318834            Appartement au coeur du Marais
# 4           4     1677091                       Lovely & Quiet flat
#
#            type   city                  neighborhood   latitude  longitude  \
# 0  private_room  Paris             2e arrondissement  48.869292   2.348335
# 1   entire_home  Paris                           NaN  48.867284   2.403255
# 2  private_room  Paris                           NaN  48.867894   2.375897
# 3   entire_home  Paris                    République  48.870370   2.358510
# 4   entire_home  Paris  Buttes-Chaumont - Belleville  48.874149   2.373700
#
#    person_capacity  beds  bedrooms  bathrooms  is_rebookable  is_new_listing  \
# ...

# %%
df_price_availability.head()
# Out:
#    listing_id         day                       created  available  \
# 0     9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1     9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2    20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3    20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4    20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
#
#   local_currency  local_price  min_nights
# 0            EUR          160           1
# 1            EUR          160           1
# 2            EUR          172           2
# 3            EUR          172           2
# 4            EUR          172           2

# %%
df_merge = pds.merge(df_price_availability.groupby('listing_id')['local_price'].mean(), df_listings_final, on='listing_id')

# %%
df_merge.head()
# Out:
#    listing_id  local_price  Unnamed: 0                                name  \
# 0       56093   170.000000          12         Beau duplex dans le Marais
# 1       57207    49.952756          13            Belle Chambre pour court
# 2      114543   107.374026          19   Charming 1bdr 55m² - Eiffel Tower
# 3      149534   169.000000           9  GREAT WARM FULL APT LE HAUT MARAIS
# 4      164255    75.876209          28  Perfect place in Le Marais - Paris
#
#            type   city       neighborhood   latitude  longitude  \
# 0   entire_home  Paris  3e arrondissement  48.867284   2.358431
# 1  private_room  Paris          Vaugirard  48.846184   2.304455
# 2   entire_home  Paris                NaN  48.849530   2.290219
# 3   entire_home  Paris                NaN  48.866360   2.361844
# 4   entire_home  Paris  3e arrondissement  48.861398   2.364299
#
#    person_capacity  beds  bedrooms  bathrooms  is_rebookable  is_new_listing  \
# ...

# %%
plt.plot(df_merge["listing_id"], df_merge["local_price"])
